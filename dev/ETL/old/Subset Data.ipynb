# %% [markdown]
# https://cloud.google.com/bigquery/docs/samples/bigquery-load-table-dataframe
#
# https://stackoverflow.com/questions/57845378/appending-csv-to-bigquery-table-with-python-client
#
# https://stackoverflow.com/questions/48886761/efficiently-write-a-pandas-dataframe-to-google-bigquery

# %%
from google.cloud import bigquery
import numpy as np

def upload_data(event, context):
    client = bigquery.Client()
    
    upload_data = pd.read_csv(f"{event['bucket']}/event['name']")
    dfSubset.rename(columns={'Unnamed: 0':'RowID','following': 'n_following', 'followers':'n_followers'}, inplace=True)
    dfSubset = dfSubset.astype({'usercreatedts': np.datetime64, 'tweetcreatedts':np.datetime64, 'extractedts':np.datetime64})
    uploda_data.to_gbq('cadeira-nuvem-2122.bq_cloud_2122.db_global', if_exists = 'append')

# %%
from IPython.display import display
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_45401/876413969.py in <cell line: 2>()
#       1 from IPython.display import display
#       2 with pd.option_context('display.max_rows', 200, 'display.max_columns', 18):
# ----> 3     display(df) #need display to show the dataframe when using with in jupyter
#       4     #some pandas stuff
#
# NameError: name 'df' is not defined

# %%
import pandas as pd
import numpy as np

# %%
dfSubset = pd.read_csv('input/data.csv')
# Out:
# /home/portugapt/miniconda3/envs/cloud/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3228: DtypeWarning: Columns (15) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
dfSubset.to_csv('input/subset.csv', index=False)

# %%
with pd.option_context('display.max_rows', 230, 'display.max_columns', 18):
    display(dfSubset.head(230)) #need display to show the dataframe when using with in jupyter
    #some pandas stuff

#dfSubset.head(157)
# Out:
#      Unnamed: 0               userid         username  \
# 0       5428025  1421921881528016896         PFComCon
# 1       5428026           1473249066    EandPCartoons
# 2       5428027           1068621782  BklynContractor
# 3       5428028           1268920135   deportesfitPAN
# 4       5428029  1210952890598096897     LuciusNatter
# 5       5428030  1278595142769934336        AvanaUrho
# 6       5428031   753571509080174592        viriyabot
# 7       5428032  1457117391603867658          NEWS_W7
# 8       5428033            248694587      ivanmadrazo
# 9       5428034            816443881   stephenbourne2
# 10      5428035            823153183           olebur
# 11      5428036            208363259     Diomedes1964
# 12      5428037  1094579073517580288    TrendingDLand
# 13      5428038   702180919122206720   KlymkoNataliya
# 14      5428039            104342504           rqskye
# 15      5428040  1347964574432112642       doubloonss
# ...

# %%
dfSubset.rename(columns={'Unnamed: 0':'RowID','following': 'n_following', 'followers':'n_followers'}, inplace=True)
dfSubset = dfSubset.astype({'usercreatedts': np.datetime64, 'tweetcreatedts':np.datetime64, 'extractedts':np.datetime64})

# %%
dfSubset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 397945 entries, 0 to 397944
# Data columns (total 18 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   RowID           397945 non-null  int64
#  1   userid          397945 non-null  int64
#  2   username        397945 non-null  object
#  3   acctdesc        310233 non-null  object
#  4   location        233629 non-null  object
#  5   n_following     397945 non-null  int64
#  6   n_followers     397945 non-null  int64
#  7   totaltweets     397945 non-null  int64
#  8   usercreatedts   397945 non-null  datetime64[ns]
#  9   tweetid         397945 non-null  int64
#  10  tweetcreatedts  397945 non-null  datetime64[ns]
#  11  retweetcount    397945 non-null  int64
#  12  text            397945 non-null  object
#  13  hashtags        397945 non-null  object
#  14  language        397945 non-null  object
#  15  coordinates     77 non-null      object
# ...

# %%
dfSubset
# Out:
#           RowID               userid         username  \
# 0       5428025  1421921881528016896         PFComCon
# 1       5428026           1473249066    EandPCartoons
# 2       5428027           1068621782  BklynContractor
# 3       5428028           1268920135   deportesfitPAN
# 4       5428029  1210952890598096897     LuciusNatter
# ...         ...                  ...              ...
# 397940  5825965            416583838   melinacugliari
# 397941  5825966  1175363608198430720        CrewPup96
# 397942  5825967           2623540653  Breaking_4_News
# 397943  5825968  1443579763453349897  Bipolarunipolar
# 397944  5825969  1494227064408346634         Deramba1
#
#                                                  acctdesc  \
# 0       Timely, concise, and comprehensive source of i...
# 1                          Editorial & Political Cartoons
# 2       🇵🇷\nI'm here for the comments.\nDon't buy a st...
# 3       Notas sobre el mundo del deporte, el fitness y...
# ...
